# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import sklearn

# %%
features = ['danceability', 'energy', 'key', 'loudness', 'mode', 'acousticness']
features.extend(['instrumentalness', 'valence', 'tempo', 'duration_ms', 'time_signature'])

info = ['track_popularity','artist_popularity', 'genre_popularity', 'age']

columns = ['name','id','followers','length'] + info + features

df = pd.read_csv('spotifyPlaylistsData.csv')

# %%
fig, ax = plt.subplots(4,4,sharey=True,figsize=(20,10))

ax[0,0].scatter(df[columns[3]],np.log10(df.followers))
ax[0,0].set_xlabel(columns[3])
ax[0,0].set_ylabel('followers')
for j in range(1,16):
    ax[int(np.floor(j/4)),j%4].scatter(df[columns[j+3]],np.log10(df.followers))
    ax[int(np.floor(j/4)),j%4].set_xlabel(columns[j+3])
    if j%4==0:
        ax[int(np.floor(j/4)),j%4].set_ylabel('followers')
fig.subplots_adjust(hspace=.5)
plt.show()

# %%
# Compute the correlation matrix
corr = df.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
reg = sklearn.linear_model.LinearRegression()
reg.fit(sml.train_X,sml.train_y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
preds = reg.predict(sml.test_X)
print(sml.np.array([test_y.values, preds]).T)
# Out:
# [[  1.99605000e+05   3.38970797e+05]
#  [  2.00244000e+05   4.19593431e+05]
#  [  2.50679000e+05   9.82898872e+05]
#  [  1.25618800e+06   1.92509157e+06]
#  [  6.14769000e+05   1.81476652e+06]
#  [  1.81182000e+05   1.13362751e+06]
#  [  2.37314000e+05   9.09838498e+05]
#  [  1.31575000e+05   7.40203830e+05]
#  [  3.10404000e+05   1.33999287e+06]
#  [  3.67992000e+05   1.76755605e+06]
#  [  6.26130000e+04   9.63631061e+05]
#  [  3.66420000e+04   5.81493239e+05]
#  [  9.50060000e+04   4.97906698e+05]
#  [  4.17642000e+05   1.47763856e+06]
#  [  4.60300000e+04   6.37833487e+04]
#  [  3.96629000e+05   1.10594627e+06]
#  [  3.84290000e+04  -1.15554247e+05]
#  [  1.97857000e+05   2.14320227e+06]
#  [  4.92786000e+05   2.26901045e+06]
#  [  6.87059000e+05   2.01774978e+06]
#  [  1.03873700e+06   1.51466073e+06]
#  [  2.31088000e+05   1.36993895e+06]
#  [  3.16715000e+05   2.13909742e+06]
#  [  4.93350000e+04   7.29312487e+05]
#  [  6.05403000e+05   2.33430705e+06]
# ...
